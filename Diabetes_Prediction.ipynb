# %% [markdown]
# <a href="https://colab.research.google.com/github/Ash-wika/Diabetes_Prediction/blob/main/Diabetes_Prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Importing the dependencies**
#
# ---

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn import svm
from sklearn.metrics import accuracy_score

# %% [markdown]
# **Data Collection and Analysis**
#
# ---
#
#
# PIMA Kaggle Diabetes Dataset

# %%
# loading the dataset to Pandas dataframe
diabetes_dataset=pd.read_csv("/content/diabetes.csv")

# %%
# printing 1st 5 rows
diabetes_dataset.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
# number of rows and columns here are
diabetes_dataset.shape
# Out:
# (768, 9)

# %%
# getting the statistical measures of the data
diabetes_dataset.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %%
diabetes_dataset['Outcome'].value_counts()
# Out:
# Outcome
# 0    500
# 1    268
# Name: count, dtype: int64

# %% [markdown]
# 0 --> Non-Diabetic
# 1 --> Diabetic

# %%
diabetes_dataset.groupby('Outcome').mean()
# Out:
#          Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# Outcome
# 0           3.298000  109.980000      68.184000      19.664000   68.792000
# 1           4.865672  141.257463      70.824627      22.164179  100.335821
#
#                BMI  DiabetesPedigreeFunction        Age
# Outcome
# 0        30.304200                  0.429734  31.190000
# 1        35.142537                  0.550500  37.067164

# %%
# separating data and labels
X=diabetes_dataset.drop(columns='Outcome',axis=1) # axis=1 for columns and axis=0 for rows
Y=diabetes_dataset['Outcome']

# %%
print(X)
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age
# 0                       0.627   50
# 1                       0.351   31
# ...

# %%
print(Y)
# Out:
# 0      1
# 1      0
# 2      1
# 3      0
# 4      1
#       ..
# 763    0
# 764    0
# 765    0
# 766    1
# 767    0
# Name: Outcome, Length: 768, dtype: int64

# %% [markdown]
# **Data Standardization**

# %%
scalar=StandardScaler()

# %%
scalar.fit(X)
# Out:
# StandardScaler()

# %%
standardized_data=scalar.transform(X)

# %%
print(standardized_data)
# Out:
# [[ 0.63994726  0.84832379  0.14964075 ...  0.20401277  0.46849198
#    1.4259954 ]
#  [-0.84488505 -1.12339636 -0.16054575 ... -0.68442195 -0.36506078
#   -0.19067191]
#  [ 1.23388019  1.94372388 -0.26394125 ... -1.10325546  0.60439732
#   -0.10558415]
#  ...
#  [ 0.3429808   0.00330087  0.14964075 ... -0.73518964 -0.68519336
#   -0.27575966]
#  [-0.84488505  0.1597866  -0.47073225 ... -0.24020459 -0.37110101
#    1.17073215]
#  [-0.84488505 -0.8730192   0.04624525 ... -0.20212881 -0.47378505
#   -0.87137393]]

# %%
X=standardized_data
Y=diabetes_dataset['Outcome']

# %%
print(X)
print(Y)
# Out:
# [[ 0.63994726  0.84832379  0.14964075 ...  0.20401277  0.46849198
#    1.4259954 ]
#  [-0.84488505 -1.12339636 -0.16054575 ... -0.68442195 -0.36506078
#   -0.19067191]
#  [ 1.23388019  1.94372388 -0.26394125 ... -1.10325546  0.60439732
#   -0.10558415]
#  ...
#  [ 0.3429808   0.00330087  0.14964075 ... -0.73518964 -0.68519336
#   -0.27575966]
#  [-0.84488505  0.1597866  -0.47073225 ... -0.24020459 -0.37110101
#    1.17073215]
#  [-0.84488505 -0.8730192   0.04624525 ... -0.20212881 -0.47378505
#   -0.87137393]]
# 0      1
# 1      0
# 2      1
# 3      0
# 4      1
#       ..
# 763    0
# 764    0
# 765    0
# 766    1
# 767    0
# Name: Outcome, Length: 768, dtype: int64

# %% [markdown]
# **Train Test Split**
#
# ---

# %%
# split X into 2 sets = 1st to train and 2nd one to test it
# same with Y
# ML model should not see the test data
# test size is for how much data you want the model to go for testing, here, 20%
# stratify in Y as it has only 0,1... if not used then all diabetic data would go to X and all non-diabetic would go to Y
# random state a seed value that initializes a random number generator. This ensures that the same random numbers are generated each time the code is run, which can be useful for debugging and reproducibility.
X_train, X_test, Y_train, Y_test=train_test_split(X,Y, test_size=0.2, stratify=Y, random_state=2)

# %%
print(X.shape, X_train.shape, X_test.shape)
# Out:
# (768, 8) (614, 8) (154, 8)

# %% [markdown]
# **Training the Model**
#
# ---

# %%
classifier=svm.SVC(kernel='linear')

# %%
#training the SVM classifier
classifier.fit(X_train, Y_train)
# Out:
# SVC(kernel='linear')

# %% [markdown]
# **Model Evaluation**
#
# ---

# %% [markdown]
# Accuracy Score

# %%
# accuracy score on the training data
X_train_prediction=classifier.predict(X_train)
training_data_accuracy=accuracy_score(X_train_prediction, Y_train)

# %%
print('Accuracy score of the training data: ', training_data_accuracy)
# Out:
# Accuracy score of the training data:  0.7866449511400652

# %%
# accuracy score on the test data
X_test_prediction=classifier.predict(X_test)
test_data_accuracy=accuracy_score(X_test_prediction, Y_test)

# %%
print('Accuracy of the test data: ',test_data_accuracy)
# Out:
# Accuracy of the test data:  0.7727272727272727

# %% [markdown]
# **Making a Predictive System**
#
# ---

# %%
input_data=(4,110,92,0,0,37.6,0.191,30)

#changing the input_data into numpy array
input_data_as_numpy_array=np.asarray(input_data)

# reshape the array as we are predictiong for one instance
input_data_reshape=input_data_as_numpy_array.reshape(1,-1)

# as we have standardized data so now we have to convert input data into standard form
std_data=scalar.transform(input_data_reshape)
print(std_data)

# classifier has the model
prediction=classifier.predict(std_data)
print('Prediction is: ',prediction)

if prediction[0]==0:
  print('Non-Diabetic')
else:
  print('Diabetic')
# Out:
# [[ 0.04601433 -0.34096773  1.18359575 -1.28821221 -0.69289057  0.71168975
#   -0.84827977 -0.27575966]]
# Prediction is:  [0]
# Non-Diabetic
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(

# %% [markdown]
# ---
#
#
#
# ---

# %%
# !pip install h5py==3.8.0
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.6/4.6 MB 25.5 MB/s eta 0:00:00
# ...
#   Attempting uninstall: h5py
#     Found existing installation: h5py 3.12.1
#     Uninstalling h5py-3.12.1:
#       Successfully uninstalled h5py-3.12.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow 2.17.1 requires h5py>=3.10.0, but you have h5py 3.8.0 which is incompatible.
# ...

# %%
import tensorflow as tf

# Define the model
model = tf.keras.models.Sequential([
  tf.keras.layers.Dense(128, activation='relu', input_shape=(X_train.shape[1],)),
  tf.keras.layers.Dense(64, activation='relu'),
  tf.keras.layers.Dense(1, activation='sigmoid')
])

# Compile the model
model.compile(optimizer='adam',
              loss='binary_crossentropy',
              metrics=['accuracy'])

# Train the model
model.fit(X_train, Y_train, epochs=100, batch_size=32)

# Evaluate the model
_, accuracy = model.evaluate(X_test, Y_test)
print('Accuracy: {}'.format(accuracy))

# Save the model
model.save('diabetes_model.h5')
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 3s 34ms/step - accuracy: 0.6836 - loss: 0.6199
# Epoch 2/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7600 - loss: 0.5054
# Epoch 3/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7755 - loss: 0.4549
# Epoch 4/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7881 - loss: 0.4124
# Epoch 5/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7709 - loss: 0.4648
# Epoch 6/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7933 - loss: 0.4503
# Epoch 7/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8107 - loss: 0.3922
# Epoch 8/100
# ...

# %%
import tensorflow as tf
import numpy as np

# Load the model
model = tf.keras.models.load_model('diabetes_model.h5')

# Get input from the user for each feature
Pregnancies = float(input("Enter the number of pregnancies: "))
Glucose = float(input("Enter the Glucose level: "))
BloodPressure = float(input("Enter the Blood Pressure: "))
SkinThickness = float(input("Enter the Skin Thickness: "))
Insulin = float(input("Enter the Insulin level: "))
BMI = float(input("Enter the BMI: "))
DiabetesPedigreeFunction = float(input("Enter the Diabetes Pedigree Function: "))
Age = float(input("Enter the Age: "))

# Create a list of input features
input_data = [Pregnancies, Glucose, BloodPressure, SkinThickness, Insulin, BMI, DiabetesPedigreeFunction, Age]

# Convert input data to numpy array and reshape
input_data_as_numpy_array = np.asarray(input_data)
input_data_reshaped = input_data_as_numpy_array.reshape(1, -1)

# Standardize the input data
std_data = scalar.transform(input_data_reshaped)

# Make the prediction
prediction = model.predict(std_data)

# Print the prediction
print('Prediction:', prediction)

# Interpret the prediction
if prediction[0][0] > 0.5:
  print('Diabetic')
else:
  print('Non-Diabetic')
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Enter the number of pregnancies: 0
# Enter the Glucose level: 100
# Enter the Blood Pressure: 98
# Enter the Skin Thickness: 0
# Enter the Insulin level: 0
# Enter the BMI: 20
# Enter the Diabetes Pedigree Function: 0.120
# Enter the Age: 20
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 201ms/step
# Prediction: [[3.724465e-07]]
# Non-Diabetic
